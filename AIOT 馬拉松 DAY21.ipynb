# %% [markdown]
# ## 作業1:

# %% [markdown]
# - yolov3_training.cfg
# - obj.names
# - obj.classes

# %% [markdown]
# ## 作業2:

# %% [markdown]
# sed -i 直接修改內容而不作顯示輸出

# %% [markdown]
# ## 作業3:

# %% [markdown]
# echo-e可以讓特定\n、\r不作文字輸出

# %% [markdown]
# ## 作業4:

# %% [markdown]
# ![image.png](attachment:image.png)
