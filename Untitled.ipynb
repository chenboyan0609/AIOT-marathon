# %% [markdown]
# ## 作業1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 作業2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 作業3

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
