# %% [markdown]
# ## 作業1:

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/', methods=['GET'])
def index():
    name = request.args.get('name')
    return "Hello " + name

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 作業2:

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/', methods=['POST'])
def index():
    name = request.form.get('name')
    passwd = request.form.get('passwd')
    return "Your name: " + name + ", Your passwd: " + passwd

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 作業3:

# %%
from flask import Flask, render_template,request

app = Flask(__name__)
 
@app.route('/')
def main():
    return render_template('test.htm')
    
@app.route('/upload', methods=['POST'])
def index():
    file = request.files['file']
    file.save(file.filename) 
    return file.filename
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/Jul/2021 13:11:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jul/2021 13:11:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jul/2021 13:11:46] "POST /upload HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)
